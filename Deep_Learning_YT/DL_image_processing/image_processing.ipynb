# %% [markdown]
# Understand the image dimension is height * weidth
#
# example 200 * 200
#
# it can be concidered image divided to 200 boxes in horizondal and vertical it is called pixel so total pixel in example is 40000, number of pixel increas the reselution increas.
#
# 480p tv is 720 * 480
# 720p is  1280*720
#
#
# type of image
#
# grayscale and RGB
#
# grayscale has 1 channel
#
# RGB has 3 channel

# %% [markdown]
# how convert gray scale to numerical value
#
# example we have 200*200 image size
# total pixel 40000
# so the image can represent a 200*200 metrix
#
# so each box has values ranges from 0 to 255
#
# 0 means black and 255 means white
#
# this represent the intensity of white colour
#
# this values feed to neural network
#
#
#
#
# How process the RGB colour
#
# it has 3D metrix each matrix represent each colour intensity RGB

# %%
# Reading an image file and converting to numpy array
# resizing the image
# converting the image to gray scale

# libraries
import cv2
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = mpimg.imread('/home/muhammed-shafeeh/AI_ML/Ai-and-Ml/Deep_Learning_YT/DL_image_processing/dog')

# %%
img.shape
# Out:
# (225, 225, 3)

# %%
print(img)
# Out:
# [[[144 122  37]
#   [153 133  44]
#   [162 143  48]
#   ...
#   [241 241 251]
#   [241 241 251]
#   [240 240 250]]
#
#  [[155 133  48]
#   [162 141  52]
#   [165 146  51]
#   ...
#   [241 241 251]
#   [241 241 251]
#   [240 240 250]]
#
#  [[161 137  51]
#   [164 143  54]
#   [166 146  51]
#   ...
#   [241 241 251]
#   [241 241 251]
#   [240 240 250]]
#
#  ...
#
#  [[153 146  65]
#   [151 146  64]
#   [144 137  56]
#   ...
#   [144 142  59]
#   [149 146  65]
#   [148 142  64]]
#
#  [[148 143  61]
#   [148 143  61]
#   [141 136  54]
#   ...
#   [153 148  66]
#   [150 145  64]
#   [148 142  64]]
#
#  [[140 135  53]
#   [134 129  47]
#   [124 119  37]
#   ...
#   [153 146  66]
#   [149 142  64]
#   [153 146  68]]]

# %%
# displaying the image
# off the mark of the image

plt.imshow(img)

# %%
# resizing the image using PIL

from PIL import Image
img = Image.open('/home/muhammed-shafeeh/AI_ML/Ai-and-Ml/Deep_Learning_YT/DL_image_processing/dog')
img = img.resize((200, 200))

# %%
plt.imshow(img)

# %%
img.save('resized_dog.png')

# %%
img_resized = mpimg.imread('/home/muhammed-shafeeh/AI_ML/Ai-and-Ml/Deep_Learning_YT/DL_image_processing/resized_dog.png')

# %%
# image resizing using opencv
img = cv2.imread('/home/muhammed-shafeeh/AI_ML/Ai-and-Ml/Deep_Learning_YT/DL_image_processing/dog')
img = cv2.resize(img, (200, 200))
cv2.imwrite('resized_dog.jpg', img)
# Out:
# True

# %%
plt.imshow(img_resized)

# %%
img_resized.shape
# Out:
# (200, 200, 3)

# %%
type(img_resized)
# Out:
# numpy.ndarray

# %%
# comverting to gray scale
img = cv2.imread("/home/muhammed-shafeeh/AI_ML/Ai-and-Ml/Deep_Learning_YT/DL_image_processing/resized_dog.jpg")
print(type(img))
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Out:
# <class 'numpy.ndarray'>

# %%
plt.imshow(img_gray, cmap='gray')

# %%
print(img_gray.shape)
print(img_gray)
# Out:
# (200, 200)
# [[121 130 139 ... 242 241 241]
#  [130 138 143 ... 242 241 241]
#  [134 138 138 ... 242 242 241]
#  ...
#  [140 137 128 ... 127 135 136]
#  [137 133 124 ... 139 139 136]
#  [126 121 111 ... 136 137 137]]

# %%
#cv2.imshow('Gray Image', img_gray)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
